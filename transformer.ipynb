# %% [markdown]
# # トランスフォーマによる将来予測
# <参考>
# * https://keras.io/examples/nlp/text_classification_with_transformer/
# * https://keras.io/examples/timeseries/timeseries_transformer_classification/

# %%
import IPython.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import random
import os


def set_seed(seed=200):
    """
    乱数シードを固定するための関数
    """
    tf.random.set_seed(seed)

    # optional
    # for numpy.random
    np.random.seed(seed)
    # for built-in random
    random.seed(seed)
    # for hash seed
    os.environ["PYTHONHASHSEED"] = str(seed)

# %% [markdown]
# ## 1.日平均気温データを読み込む

# %%
# https://www.data.jma.go.jp/gmd/risk/obsdl/index.php　よりダウンロードした日平均気温を読み込む
df = pd.read_csv('temperature_tokyo_2002-2021.csv', encoding='shift-jis', skiprows=2)

dic_stations = {"東京":"tokyo","名古屋":"nagoya","大阪":"osaka","福岡":"fukuoka"}

# 不要行を落とす
li_col = []
for i in range(df.shape[1]):
    if df.iloc[1,i] in ["品質情報","均質番号"]:
        li_col.append(df.columns[i])
df.drop(columns=li_col, inplace=True)
df.drop(index=[0,1], inplace=True)

# データを整える
df.rename(columns={"Unnamed: 0":"date"}, inplace=True)
df.rename(columns=dic_stations, inplace=True)
df.set_index("date", inplace=True)
df = df.astype(float)
df.index = pd.DatetimeIndex(df.index)

print(df.shape)
display(df.head())
display(df.tail())
# Out:
# (7305, 1)
#             tokyo
# date
# 2002-01-01    7.1
# 2002-01-02    5.2
# 2002-01-03    4.1
# 2002-01-04    6.5
# 2002-01-05    5.7
#             tokyo
# date
# 2021-12-27    2.7
# 2021-12-28    3.8
# 2021-12-29    4.2
# 2021-12-30    6.5
# 2021-12-31    3.2

# %% [markdown]
# ## 2.地点を選択する

# %%
station = "tokyo"
df_y = df[[station]].copy()
df_y.rename(columns={station:"y"}, inplace=True)
display(df_y.head())

# 折れ線グラフ
plt.figure(figsize=(10,3))
fig = sns.lineplot(data=df_y, x="date",  y="y")
plt.xticks(rotation=90)
plt.title("Time series plot")
plt.show()
# Out:
#               y
# date
# 2002-01-01  7.1
# 2002-01-02  5.2
# 2002-01-03  4.1
# 2002-01-04  6.5
# 2002-01-05  5.7

# %% [markdown]
# ## 3.部分時系列に変換する

# %%
# 窓の大きさを設定する
max_lag = 60

df_Xy = df_y.copy()

# 部分時系列をつくる
for lag in range(1,max_lag+1):
    df_Xy["x%s"%lag] = df_Xy["y"].shift(lag)
df_Xy.head()
# Out:
#               y   x1   x2   x3   x4  x5  x6  x7  x8  x9  ...  x51  x52  x53  \
# date                                                     ...
# 2002-01-01  7.1  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
# 2002-01-02  5.2  7.1  NaN  NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
# 2002-01-03  4.1  5.2  7.1  NaN  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
# 2002-01-04  6.5  4.1  5.2  7.1  NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
# 2002-01-05  5.7  6.5  4.1  5.2  7.1 NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
#
#             x54  x55  x56  x57  x58  x59  x60
# date
# 2002-01-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2002-01-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2002-01-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2002-01-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2002-01-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# ## 4.データセットを作る

# %%
# 欠損を含む行を削除する
df_Xy.dropna(inplace=True)

X = df_Xy.drop(axis=1, labels="y")
y = df_Xy[["y"]]

display(X.head())
display(y.head())

# 訓練データとテストデータに分ける
X_train = X.loc[:"2020-12-31"]
y_train = y.loc[:"2020-12-31"]
X_test = X.loc["2021-01-01":]
y_test = y.loc["2021-01-01":]

# 標準化
std_X = StandardScaler()
X_train_std = std_X.fit_transform(X_train)
X_test_std = std_X.transform(X_test)
std_y = StandardScaler()
y_train_std = std_y.fit_transform(y_train)
y_test_std = std_y.transform(y_test)

X_train = pd.DataFrame(X_train_std, index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(X_test_std, index=X_test.index, columns=X_test.columns)
y_train = pd.DataFrame(y_train_std, index=y_train.index, columns=y_train.columns)
y_test = pd.DataFrame(y_test_std, index=y_test.index, columns=y_test.columns)

# 検証データを作る
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.3, random_state=1234)

# 配列形状を(バッチサイズ, タイムステップ数, 特徴量数） にする
X_train = X_train.values[:, :, np.newaxis]
X_valid = X_valid.values[:, :, np.newaxis]
X_test = X_test.values[:, :, np.newaxis]

display(X_train.shape)
display(X_valid.shape)
display(X_test.shape)
display(y_train.shape)
display(y_valid.shape)
display(y_test.shape)
# Out:
#               x1    x2    x3    x4    x5    x6    x7    x8    x9   x10  ...  \
# date                                                                    ...
# 2002-03-02  12.0  10.3  10.9   9.5   8.3   8.9  10.8  12.5  10.6   9.0  ...
# 2002-03-03  12.3  12.0  10.3  10.9   9.5   8.3   8.9  10.8  12.5  10.6  ...
# 2002-03-04   6.3  12.3  12.0  10.3  10.9   9.5   8.3   8.9  10.8  12.5  ...
# 2002-03-05   8.5   6.3  12.3  12.0  10.3  10.9   9.5   8.3   8.9  10.8  ...
# 2002-03-06   9.1   8.5   6.3  12.3  12.0  10.3  10.9   9.5   8.3   8.9  ...
#
#              x51   x52   x53   x54  x55  x56  x57  x58  x59  x60
# date
# 2002-03-02   8.2   7.5   7.4   4.3  5.6  5.7  6.5  4.1  5.2  7.1
# 2002-03-03  10.1   8.2   7.5   7.4  4.3  5.6  5.7  6.5  4.1  5.2
# 2002-03-04  10.4  10.1   8.2   7.5  7.4  4.3  5.6  5.7  6.5  4.1
# 2002-03-05  10.2  10.4  10.1   8.2  7.5  7.4  4.3  5.6  5.7  6.5
# 2002-03-06   9.1  10.2  10.4  10.1  8.2  7.5  7.4  4.3  5.6  5.7
#
# [5 rows x 60 columns]
#                y
# date
# 2002-03-02  12.3
# 2002-03-03   6.3
# 2002-03-04   8.5
# 2002-03-05   9.1
# 2002-03-06  10.3
# (4816, 60, 1)
# (2064, 60, 1)
# (365, 60, 1)
# (4816, 1)
# (2064, 1)
# (365, 1)

# %% [markdown]
# ## 5.計算結果を格納するdictを定義する

# %%
performance_train = {}
performance_valid = {}
performance_test = {}

# %% [markdown]
# ## 6.計算を実行するための関数を定義する

# %%
def compile_and_fit(model, X_train, y_train, X_valid, y_valid, patience=2, MAX_EPOCHS=20, learning_rate=0.001,batch_size=32):
    # 早期終了の設定
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

    # 学習条件の設定
    model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(learning_rate=learning_rate),
                metrics=[tf.metrics.MeanAbsoluteError()])


    
     # 学習の実行
    history = model.fit(
                      x=X_train,
                      y=y_train,
                      batch_size=batch_size,
                      epochs=MAX_EPOCHS,
                      validation_data=(X_valid, y_valid),
                      callbacks=[early_stopping])

    # ネットワーク構造の表示
    print()
    print(model.summary())
    
    return history

# %% [markdown]
# ## 7.ネットワークを定義する

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = tf.keras.layers.Dropout(dropout)(x)
    res = x + inputs

    # フィードフォワード部分
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(res)
    x = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = tf.keras.Input(shape=input_shape)
    x = inputs
    
    # ネットワークを簡単にするため、ポジションエンベディングはモデル化していない

    # トラスフォーマブロック
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = tf.keras.layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = tf.keras.layers.Dense(dim, activation="relu")(x)
        x = tf.keras.layers.Dropout(mlp_dropout)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    return tf.keras.Model(inputs, outputs)

# %% [markdown]
# ## 8.トランスフォーマの学習を行う

# %%
# 乱数シードの固定
set_seed(seed=1234)

# モデルの定義
input_shape = X_train.shape[1:]
trans = build_model(
    input_shape,
    head_size=32, # ヘッド内の特徴量の次元
    num_heads=5, # ヘッド数
    ff_dim=32, # フィードフォワード部分の特徴量の次元数
    num_transformer_blocks=1, # トランスフォーマブロックの数
    mlp_units=[128], # 最後の全結合層の数およびそのノード数（リスト形式で指定）
    mlp_dropout=0.4, # ドロップアウト率
    dropout=0.25, # ドロップアウト率
)

# 学習
history = compile_and_fit(trans, X_train, y_train, X_valid, y_valid, MAX_EPOCHS=100, learning_rate=0.01, batch_size=1024)

# 評価
performance_train['TRANSFORMER'] = trans.evaluate(X_train, y_train)
performance_valid['TRANSFORMER'] = trans.evaluate(X_valid, y_valid)
performance_test['TRANSFORMER'] = trans.evaluate(X_test, y_test, verbose=0)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 14s 142ms/step - loss: 2.6603 - mean_absolute_error: 1.2061 - val_loss: 1.1321 - val_mean_absolute_error: 0.8171
# Epoch 2/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2878 - mean_absolute_error: 0.8540 - val_loss: 0.5735 - val_mean_absolute_error: 0.5965
# Epoch 3/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.8508 - mean_absolute_error: 0.6981 - val_loss: 0.1976 - val_mean_absolute_error: 0.3578
# Epoch 4/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.4968 - mean_absolute_error: 0.5674 - val_loss: 0.2592 - val_mean_absolute_error: 0.4256
# Epoch 5/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3092 - mean_absolute_error: 0.4459 - val_loss: 0.1668 - val_mean_absolute_error: 0.3242
# Epoch 6/100
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2610 - mean_absolute_error: 0.4023 - val_loss: 0.1168 - val_mean_absolute_error: 0.2735
# Epoch 7/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1853 - mean_absolute_error: 0.3451 - val_loss: 0.1369 - val_mean_absolute_error: 0.2982
# Epoch 8/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1734 - mean_absolute_error: 0.3359 - val_loss: 0.1053 - val_mean_absolute_error: 0.2559
# Epoch 9/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1534 - mean_absolute_error: 0.3072 - val_loss: 0.1035 - val_mean_absolute_error: 0.2540
# Epoch 10/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1362 - mean_absolute_error: 0.2930 - val_loss: 0.1083 - val_mean_absolute_error: 0.2625
# Epoch 11/100
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1366 - mean_absolute_error: 0.2950 - val_loss: 0.0992 - val_mean_absolute_error: 0.2503
# Epoch 12/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1297 - mean_absolute_error: 0.2866 - val_loss: 0.0972 - val_mean_absolute_error: 0.2469
# Epoch 13/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1188 - mean_absolute_error: 0.2752 - val_loss: 0.0963 - val_mean_absolute_error: 0.2468
# Epoch 14/100
# 5/5 [==============================] - 0s 95ms/step - loss: 0.1193 - mean_absolute_error: 0.2756 - val_loss: 0.0931 - val_mean_absolute_error: 0.2418
# Epoch 15/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.1161 - mean_absolute_error: 0.2706 - val_loss: 0.0916 - val_mean_absolute_error: 0.2398
# Epoch 16/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1130 - mean_absolute_error: 0.2687 - val_loss: 0.0915 - val_mean_absolute_error: 0.2406
# Epoch 17/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1075 - mean_absolute_error: 0.2627 - val_loss: 0.0893 - val_mean_absolute_error: 0.2362
# Epoch 18/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.1083 - mean_absolute_error: 0.2609 - val_loss: 0.0887 - val_mean_absolute_error: 0.2368
# Epoch 19/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1068 - mean_absolute_error: 0.2592 - val_loss: 0.0871 - val_mean_absolute_error: 0.2340
# Epoch 20/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1035 - mean_absolute_error: 0.2539 - val_loss: 0.0858 - val_mean_absolute_error: 0.2315
# Epoch 21/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1055 - mean_absolute_error: 0.2570 - val_loss: 0.0857 - val_mean_absolute_error: 0.2321
# Epoch 22/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1047 - mean_absolute_error: 0.2555 - val_loss: 0.0840 - val_mean_absolute_error: 0.2291
# Epoch 23/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1024 - mean_absolute_error: 0.2529 - val_loss: 0.0833 - val_mean_absolute_error: 0.2280
# Epoch 24/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.1026 - mean_absolute_error: 0.2531 - val_loss: 0.0825 - val_mean_absolute_error: 0.2269
# Epoch 25/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1001 - mean_absolute_error: 0.2507 - val_loss: 0.0822 - val_mean_absolute_error: 0.2271
# Epoch 26/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1002 - mean_absolute_error: 0.2514 - val_loss: 0.0815 - val_mean_absolute_error: 0.2249
# Epoch 27/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0970 - mean_absolute_error: 0.2452 - val_loss: 0.0810 - val_mean_absolute_error: 0.2248
# Epoch 28/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0974 - mean_absolute_error: 0.2471 - val_loss: 0.0796 - val_mean_absolute_error: 0.2213
# Epoch 29/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0950 - mean_absolute_error: 0.2440 - val_loss: 0.0795 - val_mean_absolute_error: 0.2235
# Epoch 30/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0942 - mean_absolute_error: 0.2425 - val_loss: 0.0778 - val_mean_absolute_error: 0.2197
# Epoch 31/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0941 - mean_absolute_error: 0.2423 - val_loss: 0.0770 - val_mean_absolute_error: 0.2175
# Epoch 32/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0907 - mean_absolute_error: 0.2385 - val_loss: 0.0761 - val_mean_absolute_error: 0.2167
# Epoch 33/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0878 - mean_absolute_error: 0.2349 - val_loss: 0.0753 - val_mean_absolute_error: 0.2154
# Epoch 34/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0891 - mean_absolute_error: 0.2351 - val_loss: 0.0749 - val_mean_absolute_error: 0.2155
# Epoch 35/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0888 - mean_absolute_error: 0.2358 - val_loss: 0.0745 - val_mean_absolute_error: 0.2130
# Epoch 36/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0874 - mean_absolute_error: 0.2337 - val_loss: 0.0739 - val_mean_absolute_error: 0.2125
# Epoch 37/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0900 - mean_absolute_error: 0.2367 - val_loss: 0.0736 - val_mean_absolute_error: 0.2130
# Epoch 38/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0884 - mean_absolute_error: 0.2339 - val_loss: 0.0740 - val_mean_absolute_error: 0.2150
# Epoch 39/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0876 - mean_absolute_error: 0.2341 - val_loss: 0.0722 - val_mean_absolute_error: 0.2099
# Epoch 40/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0877 - mean_absolute_error: 0.2335 - val_loss: 0.0723 - val_mean_absolute_error: 0.2110
# Epoch 41/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0849 - mean_absolute_error: 0.2300 - val_loss: 0.0713 - val_mean_absolute_error: 0.2079
# Epoch 42/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0872 - mean_absolute_error: 0.2335 - val_loss: 0.0722 - val_mean_absolute_error: 0.2115
# Epoch 43/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0845 - mean_absolute_error: 0.2291 - val_loss: 0.0715 - val_mean_absolute_error: 0.2073
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 60, 1)]      0           []
#
#  layer_normalization (LayerNorm  (None, 60, 1)       2           ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 60, 1)       1121        ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 60, 1)        0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 60, 1)       0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 60, 1)       2           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 60, 32)       64          ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 60, 32)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 60, 1)        33          ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 60, 1)       0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  global_average_pooling1d (Glob  (None, 60)          0           ['tf.__operators__.add_1[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          7808        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 9,159
# Trainable params: 9,159
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 151/151 [==============================] - 0s 3ms/step - loss: 0.0646 - mean_absolute_error: 0.1959
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0715 - mean_absolute_error: 0.2073

# %% [markdown]
# ## 9.MSEを表示する

# %%
df_train_mse = pd.DataFrame(performance_train, index=["MSE", "MAE"]).T[["MSE"]]
df_train_mse.rename(columns={"MSE":"train"}, inplace=True)
df_valid_mse = pd.DataFrame(performance_valid, index=["MSE", "MAE"]).T[["MSE"]]
df_valid_mse.rename(columns={"MSE":"valid"}, inplace=True)
df_test_mse = pd.DataFrame(performance_test, index=["MSE", "MAE"]).T[["MSE"]]
df_test_mse.rename(columns={"MSE":"test"}, inplace=True)

df_performance = pd.concat([df_train_mse,df_valid_mse, df_test_mse], axis=1)
df_performance = df_performance.loc[["TRANSFORMER"]]
plt.figure(figsize=(6,2))
df_performance.plot.bar()
plt.ylabel("MSE")
plt.legend(bbox_to_anchor=(1.2,1.))
plt.show()

# %% [markdown]
# ## 10.予測性能を評価する

# %%
def graph_scatter(y, y_pred, title):  
    """正解と予測の散布図を描くための関数"""    
    y = y["y"].values.flatten()    
    min_ = min(y.min(), y_pred.min())
    max_ = max(y.max(), y_pred.max())
    plt.figure(figsize=(4,4))
    sns.scatterplot(x=y, y=y_pred)
    plt.title(title)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.xlim([min_, max_])
    plt.ylim([min_, max_])
    plt.show()

    
def graph_line(y_train, y_test, y_test_pred):
    """折れ線グラフを描くための関数"""
    df_train = pd.DataFrame(y_train).copy()
    df_test = pd.DataFrame(y_test).copy()
    df_test_pred = pd.DataFrame({"test_pred":y_test_pred}, index=df_test.index).rename(columns={"test_pred":"y"})

    df_train["series"] = "train"
    df_test["series"] = "test"
    df_test_pred["series"] = "test_pred"
    df_result = pd.concat([df_train, df_test, df_test_pred], axis=0).reset_index()

    # 折れ線グラフ
    plt.figure(figsize=(10,3))
    fig = sns.lineplot(data=df_result, x="date", y="y", hue="series")
    plt.xticks(rotation=90)
    plt.title("Time series plot")
    plt.show()
    

def evaluate(model, X_train, X_test, y_train, y_test):    
    """性能評価を行うための関数"""    
    y_train_pred = model.predict(X_train).flatten()
    y_test_pred = model.predict(X_test).flatten()

    # RMSE
    print("RMSE of training data ", mean_squared_error(y_train, y_train_pred)**0.5)
    print("RMSE of test data ", mean_squared_error(y_test, y_test_pred)**0.5)

    # scatter plot, train
    graph_scatter(y_train, y_train_pred, "Training data")

    # scatter plot, test
    graph_scatter(y_test, y_test_pred, "Test data")
    
    # line plot
    graph_line(y_train, y_test, y_test_pred)
        
    return  y_train_pred, y_test_pred

print("="*50)
print("TRANSFORMER")
y_train_pred, y_test_pred = evaluate(trans, X_train, X_test, y_train, y_test)
# Out:
# ==================================================
# TRANSFORMER
# 151/151 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# RMSE of training data  0.25408548566815337
# RMSE of test data  0.25676654377203156
